# %%
# !python -m venv myenv
# !source myenv\Scripts\activate

# !pip install --upgrade pip setuptools wheel
# Out:
# /bin/bash: myenvScriptsactivate: No such file or directory
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in ./.local/lib/python3.9/site-packages (24.3.1)
# Requirement already satisfied: setuptools in ./.local/lib/python3.9/site-packages (75.2.0)
# Requirement already satisfied: wheel in ./.local/lib/python3.9/site-packages (0.44.0)
# WARNING: Error parsing dependencies of pyodbc: Invalid version: '4.0.0-unsupported'

# %%
# !pip install scrapy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scrapy in ./.local/lib/python3.9/site-packages (2.11.2)
# Requirement already satisfied: Twisted>=18.9.0 in ./.local/lib/python3.9/site-packages (from scrapy) (24.10.0)
# Requirement already satisfied: cryptography>=36.0.0 in ./.local/lib/python3.9/site-packages (from scrapy) (43.0.3)
# Requirement already satisfied: cssselect>=0.9.1 in ./.local/lib/python3.9/site-packages (from scrapy) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in ./.local/lib/python3.9/site-packages (from scrapy) (1.3.2)
# Requirement already satisfied: parsel>=1.5.0 in ./.local/lib/python3.9/site-packages (from scrapy) (1.9.1)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from scrapy) (21.0.0)
# Requirement already satisfied: queuelib>=1.4.2 in ./.local/lib/python3.9/site-packages (from scrapy) (1.7.0)
# Requirement already satisfied: service-identity>=18.1.0 in ./.local/lib/python3.9/site-packages (from scrapy) (24.2.0)
# Requirement already satisfied: w3lib>=1.17.0 in ./.local/lib/python3.9/site-packages (from scrapy) (2.2.1)
# Requirement already satisfied: zope.interface>=5.1.0 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from scrapy) (5.4.0)
# Requirement already satisfied: protego>=0.1.15 in ./.local/lib/python3.9/site-packages (from scrapy) (0.3.1)
# Requirement already satisfied: itemadapter>=0.1.0 in ./.local/lib/python3.9/site-packages (from scrapy) (0.9.0)
# Requirement already satisfied: setuptools in ./.local/lib/python3.9/site-packages (from scrapy) (75.2.0)
# Requirement already satisfied: packaging in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from scrapy) (21.0)
# Requirement already satisfied: tldextract in ./.local/lib/python3.9/site-packages (from scrapy) (5.1.2)
# Requirement already satisfied: lxml>=4.4.1 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from scrapy) (4.6.3)
# Requirement already satisfied: defusedxml>=0.7.1 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from scrapy) (0.7.1)
# Requirement already satisfied: PyDispatcher>=2.0.5 in ./.local/lib/python3.9/site-packages (from scrapy) (2.0.7)
# Requirement already satisfied: cffi>=1.12 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from cryptography>=36.0.0->scrapy) (1.14.6)
# Requirement already satisfied: jmespath>=0.9.5 in ./.local/lib/python3.9/site-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: six>=1.5.2 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from pyOpenSSL>=21.0.0->scrapy) (1.16.0)
# Requirement already satisfied: attrs>=19.1.0 in ./.local/lib/python3.9/site-packages (from service-identity>=18.1.0->scrapy) (24.2.0)
# Requirement already satisfied: pyasn1 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from service-identity>=18.1.0->scrapy) (0.4.8)
# Requirement already satisfied: pyasn1-modules in ./.local/lib/python3.9/site-packages (from service-identity>=18.1.0->scrapy) (0.4.1)
# Requirement already satisfied: automat>=24.8.0 in ./.local/lib/python3.9/site-packages (from Twisted>=18.9.0->scrapy) (24.8.1)
# Requirement already satisfied: constantly>=15.1 in ./.local/lib/python3.9/site-packages (from Twisted>=18.9.0->scrapy) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in ./.local/lib/python3.9/site-packages (from Twisted>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in ./.local/lib/python3.9/site-packages (from Twisted>=18.9.0->scrapy) (24.7.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in ./.local/lib/python3.9/site-packages (from Twisted>=18.9.0->scrapy) (4.12.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from packaging->scrapy) (3.0.4)
# Requirement already satisfied: idna in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from tldextract->scrapy) (3.2)
# Requirement already satisfied: requests>=2.1.0 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from tldextract->scrapy) (2.26.0)
# Requirement already satisfied: requests-file>=1.4 in ./.local/lib/python3.9/site-packages (from tldextract->scrapy) (2.1.0)
# Requirement already satisfied: filelock>=3.0.8 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from tldextract->scrapy) (3.3.1)
# Requirement already satisfied: pycparser in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=36.0.0->scrapy) (2.20)
# Requirement already satisfied: tomli in ./.local/lib/python3.9/site-packages (from incremental>=24.7.0->Twisted>=18.9.0->scrapy) (2.0.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from requests>=2.1.0->tldextract->scrapy) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from requests>=2.1.0->tldextract->scrapy) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.4)
# WARNING: Error parsing dependencies of pyodbc: Invalid version: '4.0.0-unsupported'

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: twisted in /home/vpathaka/.local/lib/python3.9/site-packages (24.10.0)
# Requirement already satisfied: pyOpenSSL in /apps/cent7/jupyterhub/lib/python3.9/site-packages (21.0.0)
# Collecting pyOpenSSL
#   Downloading pyOpenSSL-24.2.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: attrs>=22.2.0 in /home/vpathaka/.local/lib/python3.9/site-packages (from twisted) (24.2.0)
# Requirement already satisfied: automat>=24.8.0 in /home/vpathaka/.local/lib/python3.9/site-packages (from twisted) (24.8.1)
# Requirement already satisfied: constantly>=15.1 in /home/vpathaka/.local/lib/python3.9/site-packages (from twisted) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in /home/vpathaka/.local/lib/python3.9/site-packages (from twisted) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in /home/vpathaka/.local/lib/python3.9/site-packages (from twisted) (24.7.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/vpathaka/.local/lib/python3.9/site-packages (from twisted) (4.12.2)
# Requirement already satisfied: zope-interface>=5 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from twisted) (5.4.0)
# Requirement already satisfied: cryptography<44,>=41.0.5 in /home/vpathaka/.local/lib/python3.9/site-packages (from pyOpenSSL) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from cryptography<44,>=41.0.5->pyOpenSSL) (1.14.6)
# Requirement already satisfied: idna>=2.5 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from hyperlink>=17.1.1->twisted) (3.2)
# Requirement already satisfied: setuptools>=61.0 in /home/vpathaka/.local/lib/python3.9/site-packages (from incremental>=24.7.0->twisted) (75.2.0)
# Requirement already satisfied: tomli in /home/vpathaka/.local/lib/python3.9/site-packages (from incremental>=24.7.0->twisted) (2.0.2)
# Requirement already satisfied: pycparser in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from cffi>=1.12->cryptography<44,>=41.0.5->pyOpenSSL) (2.20)
# Downloading pyOpenSSL-24.2.1-py3-none-any.whl (58 kB)
# WARNING: Error parsing dependencies of pyodbc: Invalid version: '4.0.0-unsupported'
# Installing collected packages: pyOpenSSL
# Successfully installed pyOpenSSL-24.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyodbc==4.0.32
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# error: invalid-installed-package
#
# × Cannot process installed package pyodbc 4.0.0-unsupported in '/apps/cent7/jupyterhub/lib/python3.9/site-packages' because it has an invalid version:
# │ Invalid version: '4.0.0-unsupported'
# ╰─> Starting with pip 24.1, packages with invalid versions can not be processed.
#
# hint: To proceed this package must be uninstalled.
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install scrapy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scrapy
#   Downloading Scrapy-2.11.2-py2.py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: Twisted>=18.9.0 in /home/vpathaka/.local/lib/python3.9/site-packages (from scrapy) (24.10.0)
# Requirement already satisfied: cryptography>=36.0.0 in /home/vpathaka/.local/lib/python3.9/site-packages (from scrapy) (43.0.3)
# Requirement already satisfied: cssselect>=0.9.1 in /home/vpathaka/.local/lib/python3.9/site-packages (from scrapy) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in /home/vpathaka/.local/lib/python3.9/site-packages (from scrapy) (1.3.2)
# Requirement already satisfied: parsel>=1.5.0 in /home/vpathaka/.local/lib/python3.9/site-packages (from scrapy) (1.9.1)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in /home/vpathaka/.local/lib/python3.9/site-packages (from scrapy) (24.2.1)
# Requirement already satisfied: queuelib>=1.4.2 in /home/vpathaka/.local/lib/python3.9/site-packages (from scrapy) (1.7.0)
# Requirement already satisfied: service-identity>=18.1.0 in /home/vpathaka/.local/lib/python3.9/site-packages (from scrapy) (24.2.0)
# Requirement already satisfied: w3lib>=1.17.0 in /home/vpathaka/.local/lib/python3.9/site-packages (from scrapy) (2.2.1)
# Requirement already satisfied: zope.interface>=5.1.0 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from scrapy) (5.4.0)
# Requirement already satisfied: protego>=0.1.15 in /home/vpathaka/.local/lib/python3.9/site-packages (from scrapy) (0.3.1)
# Requirement already satisfied: itemadapter>=0.1.0 in /home/vpathaka/.local/lib/python3.9/site-packages (from scrapy) (0.9.0)
# Requirement already satisfied: setuptools in /home/vpathaka/.local/lib/python3.9/site-packages (from scrapy) (75.2.0)
# Requirement already satisfied: packaging in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from scrapy) (21.0)
# Requirement already satisfied: tldextract in /home/vpathaka/.local/lib/python3.9/site-packages (from scrapy) (5.1.2)
# Requirement already satisfied: lxml>=4.4.1 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from scrapy) (4.6.3)
# Requirement already satisfied: defusedxml>=0.7.1 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from scrapy) (0.7.1)
# Requirement already satisfied: PyDispatcher>=2.0.5 in /home/vpathaka/.local/lib/python3.9/site-packages (from scrapy) (2.0.7)
# Requirement already satisfied: cffi>=1.12 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from cryptography>=36.0.0->scrapy) (1.14.6)
# Requirement already satisfied: jmespath>=0.9.5 in /home/vpathaka/.local/lib/python3.9/site-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: attrs>=19.1.0 in /home/vpathaka/.local/lib/python3.9/site-packages (from service-identity>=18.1.0->scrapy) (24.2.0)
# Requirement already satisfied: pyasn1 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from service-identity>=18.1.0->scrapy) (0.4.8)
# Requirement already satisfied: pyasn1-modules in /home/vpathaka/.local/lib/python3.9/site-packages (from service-identity>=18.1.0->scrapy) (0.4.1)
# Requirement already satisfied: automat>=24.8.0 in /home/vpathaka/.local/lib/python3.9/site-packages (from Twisted>=18.9.0->scrapy) (24.8.1)
# Requirement already satisfied: constantly>=15.1 in /home/vpathaka/.local/lib/python3.9/site-packages (from Twisted>=18.9.0->scrapy) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in /home/vpathaka/.local/lib/python3.9/site-packages (from Twisted>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in /home/vpathaka/.local/lib/python3.9/site-packages (from Twisted>=18.9.0->scrapy) (24.7.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/vpathaka/.local/lib/python3.9/site-packages (from Twisted>=18.9.0->scrapy) (4.12.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from packaging->scrapy) (3.0.4)
# Requirement already satisfied: idna in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from tldextract->scrapy) (3.2)
# Requirement already satisfied: requests>=2.1.0 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from tldextract->scrapy) (2.26.0)
# Requirement already satisfied: requests-file>=1.4 in /home/vpathaka/.local/lib/python3.9/site-packages (from tldextract->scrapy) (2.1.0)
# Requirement already satisfied: filelock>=3.0.8 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from tldextract->scrapy) (3.3.1)
# Requirement already satisfied: pycparser in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=36.0.0->scrapy) (2.20)
# Requirement already satisfied: tomli in /home/vpathaka/.local/lib/python3.9/site-packages (from incremental>=24.7.0->Twisted>=18.9.0->scrapy) (2.0.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from requests>=2.1.0->tldextract->scrapy) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from requests>=2.1.0->tldextract->scrapy) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.4)
# Downloading Scrapy-2.11.2-py2.py3-none-any.whl (290 kB)
# WARNING: Error parsing dependencies of pyodbc: Invalid version: '4.0.0-unsupported'
# Installing collected packages: scrapy
#   WARNING: The script scrapy is installed in '/home/vpathaka/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed scrapy-2.11.2

# %%
# !pip install torch torchvision
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch
#   Downloading torch-2.5.0-cp39-cp39-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting torchvision
#   Downloading torchvision-0.20.0-cp39-cp39-manylinux1_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: filelock in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from torch) (3.3.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.local/lib/python3.9/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from torch) (2.6.3)
# Requirement already satisfied: jinja2 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from torch) (2.11.3)
# Requirement already satisfied: fsspec in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from torch) (2021.8.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch)
#   Downloading triton-3.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting sympy==1.13.1 (from torch)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from sympy==1.13.1->torch) (1.2.1)
# Requirement already satisfied: numpy in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from torchvision) (1.20.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from torchvision) (8.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from jinja2->torch) (1.1.1)
# Downloading torch-2.5.0-cp39-cp39-manylinux1_x86_64.whl (906.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.5/906.5 MB 4.2 MB/s eta 0:00:0000:0100:06
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:0000:0100:06
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 1.8 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 1.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 914.6 kB/s eta 0:00:00 0:00:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 7.6 MB/s eta 0:00:0000:0100:03
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 22.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 18.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 25.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 26.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 31.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 20.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 13.3 MB/s eta 0:00:00a 0:00:01
# Downloading triton-3.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 24.7 MB/s eta 0:00:0000:0100:01
# Downloading torchvision-0.20.0-cp39-cp39-manylinux1_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 10.5 MB/s eta 0:00:0000:0100:01
# WARNING: Error parsing dependencies of pyodbc: Invalid version: '4.0.0-unsupported'
# Installing collected packages: triton, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision
#   WARNING: The scripts proton and proton-viewer are installed in '/home/vpathaka/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script isympy is installed in '/home/vpathaka/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts convert-caffe2-to-onnx, convert-onnx-to-caffe2, torchfrtrace and torchrun are installed in '/home/vpathaka/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 sympy-1.13.1 torch-2.5.0 torchvision-0.20.0 triton-3.1.0

# %%
pip uninstall brotlipy
# Out:
# Found existing installation: brotlipy 0.7.0
# Uninstalling brotlipy-0.7.0:
#   Would remove:
#     /apps/cent7/jupyterhub/lib/python3.9/site-packages/brotli
#     /apps/cent7/jupyterhub/lib/python3.9/site-packages/brotlipy-0.7.0-py3.9.egg-info
# Proceed (Y/n)?

# %%
pip install brotli

# %%
import scrapy
from scrapy.crawler import CrawlerProcess
import pandas as pd
# Out:
# /home/vpathaka/.local/lib/python3.9/site-packages/scrapy/utils/_compression.py:15: ScrapyDeprecationWarning: You have brotlipy installed, and Scrapy will use it, but Scrapy support for brotlipy is deprecated and will stop working in a future version of Scrapy. brotlipy itself is deprecated, it has been superseded by brotlicffi (not currently supported by Scrapy). Please, uninstall brotlipy and install brotli instead. brotlipy has the same import name as brotli, so keeping both installed is strongly discouraged.
#   warn(
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_46249/420420985.py in <module>
#       1 import scrapy
# ----> 2 from scrapy.crawler import CrawlerProcess
#       3 import pandas as pd
#
# ~/.local/lib/python3.9/site-packages/scrapy/crawler.py in <module>
#      25 from scrapy import Spider, signals
#      26 from scrapy.addons import AddonManager
# ---> 27 from scrapy.core.engine import ExecutionEngine
#      28 from scrapy.exceptions import ScrapyDeprecationWarning
#      29 from scrapy.extension import ExtensionManager
#
# ~/.local/lib/python3.9/site-packages/scrapy/core/engine.py in <module>
#      26
#      27 from scrapy import signals
# ---> 28 from scrapy.core.downloader import Downloader
#      29 from scrapy.core.scraper import Scraper
#      30 from scrapy.exceptions import CloseSpider, DontCloseSpider, IgnoreRequest
#
# ~/.local/lib/python3.9/site-packages/scrapy/core/downloader/__init__.py in <module>
#      14 from scrapy.resolver import dnscache
#      15 from scrapy.settings import BaseSettings
# ---> 16 from scrapy.signalmanager import SignalManager
#      17 from scrapy.utils.defer import mustbe_deferred
#      18 from scrapy.utils.httpobj import urlparse_cached
#
# ~/.local/lib/python3.9/site-packages/scrapy/signalmanager.py in <module>
#       4 from twisted.internet.defer import Deferred
#       5
# ----> 6 from scrapy.utils import signal as _signal
#       7
#       8
#
# ~/.local/lib/python3.9/site-packages/scrapy/utils/signal.py in <module>
#      18 from scrapy.exceptions import StopDownload
#      19 from scrapy.utils.defer import maybeDeferred_coro
# ---> 20 from scrapy.utils.log import failure_to_exc_info
#      21
#      22 logger = logging.getLogger(__name__)
#
# ~/.local/lib/python3.9/site-packages/scrapy/utils/log.py in <module>
#      24 from scrapy.exceptions import ScrapyDeprecationWarning
#      25 from scrapy.settings import Settings
# ---> 26 from scrapy.utils.versions import scrapy_components_versions
#      27
#      28 if TYPE_CHECKING:
#
# ~/.local/lib/python3.9/site-packages/scrapy/utils/versions.py in <module>
#      11
#      12 import scrapy
# ---> 13 from scrapy.utils.ssl import get_openssl_version
#      14
#      15
#
# ~/.local/lib/python3.9/site-packages/scrapy/utils/ssl.py in <module>
#       1 from typing import Any, Optional
#       2
# ----> 3 import OpenSSL._util as pyOpenSSLutil
#       4 import OpenSSL.SSL
#       5 import OpenSSL.version
#
# ~/.local/lib/python3.9/site-packages/OpenSSL/__init__.py in <module>
#       6 """
#       7
# ----> 8 from OpenSSL import SSL, crypto
#       9 from OpenSSL.version import (
#      10     __author__,
#
# ~/.local/lib/python3.9/site-packages/OpenSSL/SSL.py in <module>
#       9 from weakref import WeakValueDictionary
#      10
# ---> 11 from OpenSSL._util import (
#      12     StrOrBytesPath as _StrOrBytesPath,
#      13 )
#
# ImportError: cannot import name 'StrOrBytesPath' from 'OpenSSL._util' (/apps/cent7/jupyterhub/lib/python3.9/site-packages/OpenSSL/_util.py)

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- --------------------
# alabaster                          0.7.12
# alembic                            1.7.5
# anaconda-client                    1.9.0
# anaconda-navigator                 2.1.1
# anaconda-project                   0.10.1
# anyio                              3.4.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# arrow                              0.13.1
# asn1crypto                         1.4.0
# astroid                            2.6.6
# astropy                            4.3.1
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              24.2.0
# Automat                            24.8.1
# autopep8                           1.5.7
# Babel                              2.9.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bash_kernel                        0.7.2
# beautifulsoup4                     4.10.0
# binaryornot                        0.4.4
# bitarray                           2.3.0
# bkcharts                           0.2
# black                              19.10b0
# bleach                             4.0.0
# blinker                            1.4
# bokeh                              2.4.1
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# cached-property                    1.5.2
# certifi                            2021.10.8
# certipy                            0.1.3
# cffi                               1.14.6
# chardet                            4.0.0
# charset-normalizer                 2.0.4
# click                              8.0.3
# cloudpickle                        2.0.0
# clyent                             1.2.2
# colorama                           0.4.4
# conda                              4.11.0
# conda-build                        3.21.5
# conda-content-trust                0+unknown
# conda-pack                         0.6.0
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# constantly                         23.10.4
# contextlib2                        0.6.0.post1
# cookiecutter                       1.7.2
# cryptography                       43.0.3
# cssselect                          1.2.0
# cycler                             0.10.0
# Cython                             0.29.24
# cytoolz                            0.11.0
# daal4py                            2021.3.0
# dask                               2021.10.0
# debugpy                            1.4.1
# decorator                          5.1.0
# defusedxml                         0.7.1
# diff-match-patch                   20200713
# distributed                        2021.10.0
# docutils                           0.17.1
# entrypoints                        0.3
# et-xmlfile                         1.1.0
# fastcache                          1.1.0
# filelock                           3.3.1
# flake8                             3.9.2
# Flask                              1.1.2
# fonttools                          4.25.0
# fsspec                             2021.8.1
# future                             0.18.2
# gevent                             21.8.0
# glob2                              0.7
# gmpy2                              2.0.8
# greenlet                           1.1.1
# h5py                               3.3.0
# HeapDict                           1.0.1
# html5lib                           1.1
# hyperlink                          21.0.0
# idna                               3.2
# imagecodecs                        2021.8.26
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 4.8.1
# importlib-resources                5.4.0
# incremental                        24.7.2
# inflection                         0.5.1
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          6.4.1
# ipyparallel                        8.0.0
# ipython                            7.29.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.5
# isort                              5.9.3
# itemadapter                        0.9.0
# itemloaders                        1.3.2
# itsdangerous                       2.0.1
# jdcal                              1.4.1
# jedi                               0.18.0
# jeepney                            0.7.1
# Jinja2                             2.11.3
# jinja2-time                        0.2.0
# jmespath                           1.0.1
# joblib                             1.1.0
# json5                              0.9.6
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-contrib-core               0.3.3
# jupyter-contrib-nbextensions       0.5.1
# jupyter-core                       4.8.1
# jupyter-highlight-selected-word    0.2.0
# jupyter-latex-envs                 1.4.6
# jupyter-nbextensions-configurator  0.4.1
# jupyter-server                     1.13.1
# jupyter-telemetry                  0.1.0
# jupyterhub                         2.0.0
# jupyterhub-ldapauthenticator       1.3.2
# jupyterlab                         3.2.1
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.8.2
# jupyterlab-widgets                 1.0.0
# keyring                            23.1.0
# kiwisolver                         1.3.1
# lazy-object-proxy                  1.6.0
# ldap3                              2.9.1
# libarchive-c                       2.9
# llvmlite                           0.37.0
# locket                             0.2.1
# lxml                               4.6.3
# Mako                               1.1.6
# MarkupSafe                         1.1.1
# matplotlib                         3.4.3
# matplotlib-inline                  0.1.2
# mccabe                             0.6.1
# mistune                            0.8.4
# mkl-fft                            1.3.1
# mkl-random                         1.2.2
# mkl-service                        2.4.0
# mock                               4.0.3
# more-itertools                     8.10.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multipledispatch                   0.6.0
# munkres                            1.1.4
# mypy-extensions                    0.4.3
# navigator-updater                  0.2.1
# nbclassic                          0.3.4
# nbclient                           0.5.3
# nbconvert                          6.1.0
# nbformat                           5.1.3
# nest-asyncio                       1.5.1
# networkx                           2.6.3
# nltk                               3.6.5
# nose                               1.3.7
# notebook                           6.4.5
# numba                              0.54.1
# numexpr                            2.7.3
# numpy                              1.20.3
# numpydoc                           1.1.0
# nvidia-cublas-cu12                 12.4.5.8
# nvidia-cuda-cupti-cu12             12.4.127
# nvidia-cuda-nvrtc-cu12             12.4.127
# nvidia-cuda-runtime-cu12           12.4.127
# nvidia-cudnn-cu12                  9.1.0.70
# nvidia-cufft-cu12                  11.2.1.3
# nvidia-curand-cu12                 10.3.5.147
# nvidia-cusolver-cu12               11.6.1.9
# nvidia-cusparse-cu12               12.3.1.170
# nvidia-nccl-cu12                   2.21.5
# nvidia-nvjitlink-cu12              12.4.127
# nvidia-nvtx-cu12                   12.4.127
# oauthlib                           3.1.1
# olefile                            0.46
# openpyxl                           3.0.9
# packaging                          21.0
# pamela                             1.0.0
# pandas                             1.3.4
# pandocfilters                      1.4.3
# parsel                             1.9.1
# parso                              0.8.2
# partd                              1.2.0
# path                               16.0.0
# pathlib2                           2.3.6
# pathspec                           0.7.0
# patsy                              0.5.2
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.4.0
# pip                                24.3.1
# pkginfo                            1.7.1
# pluggy                             0.13.1
# ply                                3.11
# poyo                               0.5.0
# prometheus-client                  0.11.0
# prompt-toolkit                     3.0.20
# Protego                            0.3.1
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# pyasn1                             0.4.8
# pyasn1_modules                     0.4.1
# pycodestyle                        2.7.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.44.1
# PyDispatcher                       2.0.7
# pydocstyle                         6.1.1
# pyee                               8.2.2
# pyerfa                             2.0.0
# pyflakes                           2.3.1
# Pygments                           2.10.0
# PyJWT                              2.1.0
# pylint                             2.9.6
# pyls-spyder                        0.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          21.0.0
# pyparsing                          3.0.4
# pyppeteer                          0.2.6
# pyrsistent                         0.18.0
# PySocks                            1.7.1
# pytest                             6.2.4
# python-dateutil                    2.8.2
# python-json-logger                 2.0.1
# python-lsp-black                   1.0.0
# python-lsp-jsonrpc                 1.0.0
# python-lsp-server                  1.2.4
# python-slugify                     5.0.2
# pytz                               2021.3
# PyWavelets                         1.1.1
# pyxdg                              0.27
# PyYAML                             6.0
# pyzmq                              22.2.1
# QDarkStyle                         3.0.2
# qstylizer                          0.1.10
# QtAwesome                          1.0.2
# qtconsole                          5.1.1
# QtPy                               1.10.0
# queuelib                           1.7.0
# regex                              2021.8.3
# requests                           2.26.0
# requests-file                      2.1.0
# rope                               0.19.0
# Rtree                              0.9.7
# ruamel.yaml                        0.17.10
# ruamel.yaml.clib                   0.2.2
# ruamel-yaml-conda                  0.15.100
# scikit-image                       0.18.3
# scikit-learn                       0.24.2
# scikit-learn-intelex               2021.20210714.170444
# scipy                              1.7.1
# Scrapy                             2.11.2
# seaborn                            0.11.2
# SecretStorage                      3.3.1
# Send2Trash                         1.8.0
# service-identity                   24.2.0
# setuptools                         75.2.0
# simplegeneric                      0.8.1
# singledispatch                     3.7.0
# sip                                4.19.13
# six                                1.16.0
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.4.0
# soupsieve                          2.2.1
# Sphinx                             4.2.0
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             2.0.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.5
# sphinxcontrib-websupport           1.2.4
# spyder                             5.1.5
# spyder-kernels                     2.1.3
# SQLAlchemy                         1.4.22
# statsmodels                        0.12.2
# sympy                              1.13.1
# tables                             3.6.1
# TBB                                0.2
# tblib                              1.7.0
# terminado                          0.9.4
# testpath                           0.5.0
# text-unidecode                     1.3
# textdistance                       4.2.1
# threadpoolctl                      2.2.0
# three-merge                        0.1.1
# tifffile                           2021.7.2
# tinycss                            0.4
# tldextract                         5.1.2
# toml                               0.10.2
# tomli                              2.0.2
# toolz                              0.11.1
# torch                              2.5.0
# torchvision                        0.20.0
# tornado                            6.1
# tqdm                               4.62.3
# traitlets                          5.1.0
# triton                             3.1.0
# Twisted                            24.10.0
# typed-ast                          1.4.3
# typing_extensions                  4.12.2
# ujson                              4.0.2
# unicodecsv                         0.14.1
# Unidecode                          1.2.0
# urllib3                            1.26.7
# w3lib                              2.2.1
# watchdog                           2.1.3
# wcwidth                            0.2.5
# webencodings                       0.5.1
# websocket-client                   1.2.3
# websockets                         9.1
# Werkzeug                           2.0.2
# wheel                              0.44.0
# whichcraft                         0.6.1
# widgetsnbextension                 3.5.1
# wrapt                              1.12.1
# wurlitzer                          2.1.1
# xlrd                               2.0.1
# XlsxWriter                         3.0.1
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.31.0
# zict                               2.0.0
# zipp                               3.6.0
# zope.event                         4.5.0
# zope.interface                     5.4.0

# %%
source myenv/Scripts/activate
# Out:
#   File "/tmp/ipykernel_38014/1543819849.py", line 1
#     source myenv/Scripts/activate
#            ^
# SyntaxError: invalid syntax

# %%
# !pip install ipykernel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipykernel in /apps/cent7/jupyterhub/lib/python3.9/site-packages (6.4.1)
# Requirement already satisfied: ipython-genutils in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from ipykernel) (0.2.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from ipykernel) (1.4.1)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from ipykernel) (7.29.0)
# Requirement already satisfied: traitlets<6.0,>=4.1.0 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from ipykernel) (5.1.0)
# Requirement already satisfied: jupyter-client<8.0 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from ipykernel) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from ipykernel) (6.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from ipykernel) (0.1.2)
# Requirement already satisfied: setuptools>=18.5 in ./.local/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel) (0.18.0)
# Requirement already satisfied: decorator in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel) (5.1.0)
# Requirement already satisfied: pickleshare in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel) (3.0.20)
# Requirement already satisfied: pygments in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel) (2.10.0)
# Requirement already satisfied: backcall in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel) (4.8.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel) (4.8.1)
# Requirement already satisfied: pyzmq>=13 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel) (2.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from pexpect>4.3->ipython<8.0,>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel) (0.2.5)
# Requirement already satisfied: six>=1.5 in /apps/cent7/jupyterhub/lib/python3.9/site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel) (1.16.0)
# WARNING: Error parsing dependencies of pyodbc: Invalid version: '4.0.0-unsupported'

# %%
python -m ipykernel install --user --name=myenv --display-name "Python (myenv)"
# Out:
#   File "/tmp/ipykernel_38014/107052000.py", line 1
#     python -m ipykernel install --user --name=myenv --display-name "Python (myenv)"
#               ^
# SyntaxError: invalid syntax

# %%
class MsdSpider(scrapy.Spider):
    name = "msd"
    start_urls = ['https://www.msdvetmanual.com/']

    def parse(self, response):
        for article in response.css('div.article'):
            yield {
                'title': article.css('h2::text').get(),
                'content': article.css('p::text').getall(),
            }
        next_page = response.css('a.next::attr(href)').get()
        if next_page is not None:
            yield response.follow(next_page, self.parse)

# %%
process = CrawlerProcess({
    'FEED_FORMAT': 'csv',
    'FEED_URI': 'msd_data.csv',
})

process.crawl(MsdSpider)
process.start()
