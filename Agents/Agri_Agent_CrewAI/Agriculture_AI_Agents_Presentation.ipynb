# %%
#!pip install crewai
#!pip install crewai[tools]
#!pip install crewai_tools

# %%
import os
from crewai_tools import SerperDevTool, BrowserbaseLoadTool, EXASearchTool
from crewai import Agent
from crewai import Task
from crewai import LLM

from langchain_community.llms import Ollama


from crewai import Crew, Process
# Out:
# D:\anaconda\envs\py310\lib\site-packages\pydantic\_internal\_generate_schema.py:502: UserWarning: <built-in function callable> is not a Python type (it may be an instance of an object), Pydantic will allow any object with no validation since we cannot even enforce that the input is an instance of the given type. To get rid of this error wrap the type with `pydantic.SkipValidation`.
#   warn(

# %%
from crewai import Agent
#from your_library import DiseaseDatabase

# Define the Researcher Agent for Agriculture
researcher_agent = Agent(
    role="Agriculture Assistant",
    goal="Provide expert advice on crop diseases, pests, and suitable pesticides or fertilizers",
    backstory="""You're an AI-powered assistant at a university extension service, designed to support farmers by offering real-time guidance on managing crop health and optimizing inputs for better yield.""",
    tools=[SerperDevTool()],
    verbose=True
)

# %%
'''
openai_llm = LLM(
    model="gpt-4",
    api_key="your-openai-api-key",
    api_base="https://api.openai.com/v1"
)
'''

# %%
ollama_llm = LLM(
    model="ollama/llama3.2",
    base_url="http://localhost:11434"
)

# %%
llm_llama = Ollama(model="llama2")
# Out:
# C:\Users\ssrsr\AppData\Local\Temp\ipykernel_36212\3718070551.py:1: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm_llama = Ollama(model="llama2")

# %%
researcher_agent = Agent(
    role='Researcher',
    goal='Find and summarize the latest AI news',
    backstory="""You're a researcher at a large company.
    You're responsible for analyzing data and providing insights
    to the business.""",
    verbose=False,
    ## llm=llm_llama
    llm=LLM( model="ollama/llama3.2", base_url="http://localhost:11434" )
)

# %%
'''

os.environ["OPENAI_API_KEY"] = "your-openai-api-key"
os.environ["OPENAI_API_BASE"] = "https://api.openai.com/v1"

'''

# %%
## task = Task(description=""" Test """, agent = research_agent)

crop_disease_research_task = Task(
    description="Conduct comprehensive research on crop diseases and provide management strategies.",
    expected_output="A detailed report highlighting key diseases affecting crops, symptoms, treatment options, and prevention methods.",
    agent=researcher_agent,  # Make sure researcher_agent is defined as shown previously
    async_execution=True
)

'''

research_task = Task(
    description="Conduct comprehensive research on the latest AI developments.",
    expected_output="A summary report highlighting key advancements in AI.",
    agent=researcher_agent,
    ## tools=[search_tool],
    async_execution=True
)

'''
# Out:
# '\n\nresearch_task = Task(\n    description="Conduct comprehensive research on the latest AI developments.",\n    expected_output="A summary report highlighting key advancements in AI.",\n    agent=researcher_agent,\n    ## tools=[search_tool],\n    async_execution=True\n)\n\n'

# %%
'''
crew = Crew(
      agents=[research_agent],
      tasks = [research_task],
      verbose=2
)
'''

# %%
crop_disease_research_task2 = Task(
    description="Conduct comprehensive research on crop diseases and provide management strategies.",
    expected_output="What are the symptoms of a pest attack on tomato plants?",
    agent=researcher_agent,  # Make sure researcher_agent is defined as shown previously
    async_execution=False
)

# %%
my_crew = Crew(
    agents=[researcher_agent],
    tasks=[crop_disease_research_task,crop_disease_research_task2],
    process=Process.sequential,
    verbose=True
)
# Out:
# 2025-02-16 20:12:40,934 - 46376 - __init__.py-__init__:537 - WARNING: Overriding of current TracerProvider is not allowed

# %%
result = my_crew.kickoff()
print(result)
# Out:
# # Agent: Researcher
# ## Task: Conduct comprehensive research on crop diseases and provide management strategies.
#
#
# # Agent: Researcher
# ## Final Answer:
# **Crop Diseases and Management Strategies**
#
# Crops are susceptible to various diseases that can significantly impact yield, quality, and food security. Understanding the common crop diseases, their symptoms, treatment options, and prevention methods is crucial for effective management.
#
# **Common Crop Diseases**
#
# 1. **Powdery Mildew**
# Powdery mildew is a fungal disease caused by Oidium spp., causing white powdery growth on leaves, stems, and flowers. Symptoms include yellowing of leaves, premature senescence, and reduced yield.
# 2. **Downy Mildew**
# Downy mildew is caused by Peronospora spp., characterized by downy growth on the underside of leaves, yellowing, and premature defoliation.
# 3. **Rust**
# ...
